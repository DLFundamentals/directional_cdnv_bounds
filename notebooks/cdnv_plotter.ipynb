# %%
import numpy as np, json, os, sys, pandas as pd
import random
sys.path.append("../")
from bound_analysis.cdnv_viz import plot_cdnv_from_csv, plot_cdnv_from_two_csvs
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path1 = "/home/yashsalunkhe619/directional_cdnv_bounds/outputs/dino_gran.csv"
csv_path2 = "/home/yashsalunkhe619/directional_cdnv_bounds/outputs/cdnv_dino.csv"

# %%
plot_cdnv_from_two_csvs(
    csv_path1,
    csv_path2,
    output_path = output_pth,
    
    show_corr=False)
